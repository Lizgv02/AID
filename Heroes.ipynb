# %%
import numpy as np
import pandas as pd
import os
import missingno as msno

from ydata_profiling import ProfileReport
from matplotlib import cbook

# %%
df = pd.read_csv('super_hero_info.csv', header=0, sep=',')

# %%
df_marvel = df[df.Publisher == 'Marvel Comics']

df_marvel
# Out:
#      Unnamed: 0             name  Gender Eye color               Race  \
# 0             0           A-Bomb    Male    yellow              Human
# 3             3      Abomination    Male     green  Human / Radiation
# 4             4          Abraxas    Male      blue      Cosmic Entity
# 5             5    Absorbing Man    Male      blue              Human
# 8             8         Agent 13  Female      blue                  -
# ..          ...              ...     ...       ...                ...
# 726         726            X-Man    Male      blue                  -
# 727         727      Yellow Claw    Male      blue                  -
# 728         728     Yellowjacket    Male      blue              Human
# 729         729  Yellowjacket II  Female      blue              Human
# 730         730             Ymir    Male     white        Frost Giant
#
#            Hair color  Height      Publisher Skin color Alignment  Weight
# ...

# %%
df_dc = df[df.Publisher == 'DC Comics']

df_dc
# Out:
#      Unnamed: 0               name  Gender Eye color      Race Hair color  \
# 2             2           Abin Sur    Male      blue   Ungaran    No Hair
# 7             7       Adam Strange    Male      blue     Human      Blond
# 13           13         Alan Scott    Male      blue         -      Blond
# 16           16  Alfred Pennyworth    Male      blue     Human      Black
# 19           19              Amazo    Male       red   Android          -
# ..          ...                ...     ...       ...       ...        ...
# 715         715           Wildfire    Male         -         -          -
# 720         720        Wonder Girl  Female      blue  Demi-God      Blond
# 722         722       Wonder Woman  Female      blue    Amazon      Black
# 732         732            Zatanna  Female      blue     Human      Black
# 733         733               Zoom    Male       red         -      Brown
#
#      Height  Publisher Skin color Alignment  Weight
# ...

# %%
df_marvel_buenos = df_marvel[df_marvel.Alignment == 'good']

df_marvel_buenos
# Out:
#      Unnamed: 0             name  Gender Eye color            Race  \
# 0             0           A-Bomb    Male    yellow           Human
# 8             8         Agent 13  Female      blue               -
# 9             9        Agent Bob    Male     brown           Human
# 10           10       Agent Zero    Male         -               -
# 22           22            Angel    Male      blue               -
# ..          ...              ...     ...       ...             ...
# 725         725             X-23  Female     green  Mutant / Clone
# 726         726            X-Man    Male      blue               -
# 728         728     Yellowjacket    Male      blue           Human
# 729         729  Yellowjacket II  Female      blue           Human
# 730         730             Ymir    Male     white     Frost Giant
#
#            Hair color  Height      Publisher Skin color Alignment  Weight
# 0             No Hair   203.0  Marvel Comics          -      good   441.0
# ...

# %%
df_marvel_malos = df_marvel[df_marvel.Alignment == 'bad']

df_marvel_malos
# Out:
#      Unnamed: 0           name Gender Eye color               Race Hair color  \
# 3             3    Abomination   Male     green  Human / Radiation    No Hair
# 4             4        Abraxas   Male      blue      Cosmic Entity      Black
# 5             5  Absorbing Man   Male      blue              Human    No Hair
# 11           11     Air-Walker   Male      blue                  -      White
# 12           12           Ajax   Male     brown             Cyborg      Black
# ..          ...            ...    ...       ...                ...        ...
# 691         691      Venom III   Male     brown           Symbiote      Brown
# 703         703        Vulture   Male     brown              Human    No Hair
# 704         704         Walrus   Male      blue              Human      Black
# 712         712      Weapon XI   Male         -                  -          -
# 727         727    Yellow Claw   Male      blue                  -    No Hair
#
# ...

# %%
df_dc_men = df_dc[df_dc.Gender == 'Male']

df_dc_men
# Out:
#      Unnamed: 0               name Gender Eye color     Race Hair color  \
# 2             2           Abin Sur   Male      blue  Ungaran    No Hair
# 7             7       Adam Strange   Male      blue    Human      Blond
# 13           13         Alan Scott   Male      blue        -      Blond
# 16           16  Alfred Pennyworth   Male      blue    Human      Black
# 19           19              Amazo   Male       red  Android          -
# ..          ...                ...    ...       ...      ...        ...
# 680         680           Two-Face   Male         -        -          -
# 694         694               Vibe   Male     brown    Human      Black
# 708         708               Warp   Male     brown        -      Black
# 715         715           Wildfire   Male         -        -          -
# 733         733               Zoom   Male       red        -      Brown
#
#      Height  Publisher Skin color Alignment  Weight
# ...

# %%
df_dc_women = df_dc[df_dc.Gender == 'Female']

df_dc_women
# Out:
#      Unnamed: 0          name  Gender Eye color      Race Hair color  Height  \
# 51           51     Atom Girl  Female     black         -      Black   168.0
# 62           62       Batgirl  Female         -         -          -   -99.0
# 63           63       Batgirl  Female     green     Human        Red   170.0
# 64           64   Batgirl III  Female         -         -          -   -99.0
# 65           65    Batgirl IV  Female     green     Human      Black   165.0
# ..          ...           ...     ...       ...       ...        ...     ...
# 701         701         Vixen  Female     amber     Human      Black   175.0
# 713         713  White Canary  Female     brown     Human      Black   -99.0
# 720         720   Wonder Girl  Female      blue  Demi-God      Blond   165.0
# 722         722  Wonder Woman  Female      blue    Amazon      Black   183.0
# 732         732       Zatanna  Female      blue     Human      Black   170.0
#
#      Publisher Skin color Alignment  Weight
# ...
